# %% [markdown]
# # Exploratory Data Analysis - Spotify

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_track = pd.read_csv('tracks.csv')
df_track
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
df_track.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
df_track.set_index("release_date",inplace=True)
df_track.index=pd.to_datetime(df_track.index)
df_track.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %%
df_track_modified = df_track.copy()
df_track_modified
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                              ...                                  ...
# 2020-09-26    5rgu12WBIHQtvej2MdHSH0                                  云与海
# 2020-10-21    0NuWgxEp51CutD2pJoF4OM                                blind
# 2020-09-02    27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 2021-03-05    45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 2015-07-01    5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %%
columns_to_drop = ['id', 'explicit','danceability', 'energy', 'key',
                   'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
                   'liveness', 'valence', 'tempo', 'time_signature','id_artists']
columns_to_drop
# Out:
# ['id',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'id_artists']

# %%
df_track_modified = df_track_modified.drop(columns=columns_to_drop)
df_track_modified
# Out:
#                                              name  popularity  duration_ms  \
# release_date
# 1922-02-22                                  Carve           6       126903
# 1922-06-01    Capítulo 2.16 - Banquero Anarquista           0        98200
# 1922-03-21     Vivo para Quererte - Remasterizado           0       181640
# 1922-03-21          El Prisionero - Remasterizado           0       176907
# 1922-01-01                    Lady of the Evening           0       163080
# ...                                           ...         ...          ...
# 2020-09-26                                    云与海          50       258267
# 2020-10-21                                  blind          72       153293
# 2020-09-02              What They'll Say About Us          70       187601
# 2021-03-05                        A Day At A Time          58       142003
# 2015-07-01                       Mar de Emociones          38       214360
#
#                                       artists
# ...

# %% [markdown]
# ### Top 10 least Popular Songs

# %%
least_popular_songs = df_track_modified.sort_values('popularity',ascending=True).head(10)
least_popular_songs
# Out:
#                                                            name  popularity  \
# release_date
# 1935-02-20         Newspaper Reports On Abner, 20 February 1935           0
# 1949-01-01                                               恋は水の上で           0
# 1949-01-01                                                私の誕生日           0
# 1949-01-01                                  エル・チョクロ (EL CHOCLO)           0
# 1949-01-01                                             恋は不思議なもの           0
# 1949-01-01                           ゆうべはどうしたの (WHATSA MALLA U)           0
# 1949-04-10    Screen Director's Playhouse, Music For Million...           0
# 1949-01-01                                               ブルーマンボ           0
# 1949-05-19    Screen Director's Playhouse, Trade Winds direc...           0
# 1949-05-08    Screen Director's Playhouse, It's A Wonderful ...           0
#
#               duration_ms                                            artists
# release_date
# ...

# %% [markdown]
# ### Top 10 Most Popular Songs

# %%
most_popular_songs = df_track_modified.query('popularity>90',inplace=False).sort_values('popularity',ascending=False).head(10)
most_popular_songs
# Out:
#                                                 name  popularity  duration_ms  \
# release_date
# 2021-03-19    Peaches (feat. Daniel Caesar & Giveon)         100       198082
# 2021-01-08                           drivers license          99       242014
# 2021-01-06                    Astronaut In The Ocean          98       132780
# 2020-03-20                           Save Your Tears          97       215627
# 2020-12-04                                 telepatía          97       160191
# 2020-03-20                           Blinding Lights          96       200040
# 2021-03-05                       Leave The Door Open          96       242096
# 2020-09-16                              The Business          95       164000
# 2019-11-07                                   Streets          94       226987
# 2020-03-27                    Heartbreak Anniversary          94       198371
#
#                                                      artists
# release_date
# ...

# %%
df_track.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %% [markdown]
# ### correlation heatmap

# %%
corr_df = df_track.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap = sns.heatmap(corr_df,annot=True,fmt=".1g",vmin=-1,vmax=1,center=0,cmap="inferno",linewidths=1,linecolor="Black",)
heatmap.set_title("Correlation Heatmap Between Variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90);

# %%
# creating regression plot and take just 0.004 percent of the total data

sample_df = df_track.sample(int(0.004*len(df_track)))
print(len(sample_df))
# Out:
# 2346

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="Loudness vs Enery")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Enery')]

# %% [markdown]
# Observation:
# 1. If the energy increases the loudness of the sound also increases
# 2. If the loudness of the sound   decreases the energy is also decreases.

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="r").set(title="Popularity vs Acousticness")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness')]

# %% [markdown]
# Observation:
# 1. acoustiness of the song increases the popularity decreases
# 2. popularity increases the acoustiness decreases

# %%
# Converting duration_ms with duration
df_track_modified['duration']=df_track_modified['duration_ms'].apply(lambda x : round(x/1000))
df_track_modified.drop('duration_ms', inplace=True, axis=1)

# %%
df_track_modified.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
# Name: duration, dtype: int64

# %%
df_track_modified['dates']=df_track_modified.index.get_level_values('release_date')
df_track_modified.dates=pd.to_datetime(df_track_modified.dates)

# %%
years = df_track_modified.dates.dt.year

# %%
sns.displot(years, discrete=True , aspect=2, height=6, kind='hist').set(title='Number Of Song Per Years');

# %% [markdown]
# Observation:- Technology increases number of songs and their access is increases

# %% [markdown]
# # Features Dataset Analysis

# %%
df_genre = pd.read_csv("SpotifyFeatures.csv")
df_genre
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %% [markdown]
# ### Duration of Songs in different Generes

# %%
plt.title('Duration of songs in different Genres')
sns.color_palette('rocket', as_cmap=True)
sns.barplot(y='genre', x='duration_ms', data=df_genre)
plt.xlabel('Duration in milliseconds')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %% [markdown]
# Observation: Classical and world generes duration is more during to others generes

# %% [markdown]
# ### Top 5 Generes by Popularity

# %%
sns.set_style(style='darkgrid')
plt.figure(figsize=(12,6))
popular = df_genre.sort_values('popularity', ascending=False).head(10)
sns.barplot(y = 'genre', x = 'popularity', data = popular).set(title='Top 5 Genres by Popularity')
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %% [markdown]
# Observation:
# Popular gener is:-
# 1. Dance
# 2. Pop
# 3. Rap
# 4. Hip-Hop
# 5. Reggaeton
